# %% [markdown]
# <a href="https://colab.research.google.com/github/FRIDA-34/EstadisticaVerano2026/blob/main/eii_u1_05_24150720.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{yy} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df = pd.DataFrame({
 "promedio_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
    "promedio_final": [64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
})
df
# Out:
#     promedio_examenes_cortos  promedio_final
# 0                         59              64
# 1                         92              84
# 2                         72              77
# 3                         90              80
# 4                         95              77
# 5                         87              81
# 6                         89              80
# 7                         77              84
# 8                         76              80
# 9                         65              69
# 10                        97              83
# 11                        42              40
# 12                        94              78
# 13                        62              65
# 14                        91              90

# %% [markdown]
# 1.**Establesca una variable dependiente ($Y$) y una variable independiente ($X$).**

# %%
# que información tengo (x) variable independiente
# que información tengo (y) variable dependiente
Y = df["promedio_final"]
X = df["promedio_examenes_cortos"]

# %% [markdown]
# 2.**Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Promedio examenes cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Promedio final', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3.**¿Los datos soportan la suposición de linealidad?**
#
# Si porque existe una tendencia positiva y siguen una relación los puntos

# %% [markdown]
# 4.**Calcule el coeficiente de correlación e interprete el resultado.**

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.8646
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación es $r=.8646$, este valor indica que la correlación es fuerte y positiva, ya que se encuentra muy cerca de 1. Esto quiere decir que los alumnos con mejores notas en exámenes cortos tienen promedios finales más altos.

# %% [markdown]
# 5.**Calcule el coeficiente de determinación e interprete el resultado**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo=sm.OLS(Y,x_constante).fit()
y_calculada =modelo.predict(x_constante)

# %%
#Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)
print(f"Coeficiente de determinación:{r2: 0.2%}")
# Out:
# Coeficiente de determinación: 74.75%

# %% [markdown]
# El coeficiente de determinación de $r^2=74.75$ indica que la variabilidad en el promedio final se basa por el promedio obtenido en sus exámenes cortos. El 25.25% restante se debe a las variantes no incluidas.

# %% [markdown]
# 6.**Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo=sm.OLS(Y,x_constante).fit()
y_calculada =modelo.predict(x_constante)

modelo.params
# Out:
# const                       24.526822
# promedio_examenes_cortos     0.643180
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
# $$
# \hat{y}= 24.526822+0.643180x
# $$
# Donde x es el promedio de examenes cortos

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)


# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Promedio de examenes cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Promedio final', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 7.**Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b1$)**

# %%
#intervalos de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                                  0          1
# const                     6.441997  42.611646
# promedio_examenes_cortos  0.419219   0.867141

# %%
24.5268+0.643180*(59)
# Out:
# 62.47442

# %% [markdown]
# En $b_0$ verdadero se encuentra entre $6.441997$ y $42.611646$ este muestra el promedio final esperado para un alumno que saco 0 con un 95% de confianza.
#
#
# Teniendo el 95% de confianza $b_1$ esta entre $0.419219$ y $0.867141$ hay una relación positiva, de igual forma muestra que por cada punto que aumente el promedio de exámenes cortos de igual manera aumenta el promedio final.

# %% [markdown]
# 8.**Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Calcular los residuales
residuales = Y - y_calculada

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50                  # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Promedio examenes cortos', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Promedio final', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--', # Corrected: Removed the extra 'S'
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# Para los supuestos
# + Linealidad: Si cumple, ya que existe una relación entre las variables.
# + Normalidad: Se cumple correctamente ya que siguen una distribución normal.
# + Homoscedasticidad: Si se cumple ya que la distancia de los puntos tienen una dispersión uniforme.
# + Independencia: Si cumple ya que son datos distintos por cada alumno.

# %% [markdown]
# 9.**Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro es el mas confiable
# n > 30, Histograma o Q-Q plot


#test de Shapiro-Wilk
1
#H0: Hay normalidad  0.0.4172971767713699
#H1: No hay normalidad


# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.901827735700704

# %% [markdown]
# Dado que obtuvimos el $valor-p= 0.9018$ y comparandolo con el nivel de significancia $\alpha = 0.05$ podemos ver que es mayor y por esto mismo no se rechaza la hipótesis nula ($H_0$)

# %% [markdown]
# 10.**Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.2289

# %% [markdown]
# Dado que obtuvimos que el $valor_p$ es de $0.2289$ comparandolo con nuestro nivel de significancia $\alpha=0.05$, es mayor el $valor_p$ asi que no se rechaza la hipotesis nula $(H_0)$

# %% [markdown]
# 11.**Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?**

# %%
valores_a_predecir =[70, 75, 84]
print(" Resultados esperados (Predicciones):")
for val in valores_a_predecir:
  pred = modelo.predict([1, val])[0]
  print(f"   Para X = {val} -> Y estimado = {pred:.2f}")
  print("")
#
# Out:
#  Resultados esperados (Predicciones):
#    Para X = 70 -> Y estimado = 69.55
#
#    Para X = 75 -> Y estimado = 72.77
#
#    Para X = 84 -> Y estimado = 78.55

# %% [markdown]
# 12.**Realice una tabla ANOVA e interprete el resultado.**

# %%
import pandas as pd

# Re-create the DataFrame for Problem 1 to ensure correct data is used
df = pd.DataFrame({
 "promedio_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
    "promedio_final": [64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
})

# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols(
    '''promedio_final ~ promedio_examenes_cortos''',
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova

print("11. Tabla ANOVA:")
print(tabla_anova)
print("\nInterpretación de ANOVA:")
print("  El valor-p (PR(>F)) es extremadamente bajo (0.000032 < 0.05), por lo que")
print("  se rechaza H0. El modelo de regresión lineal es estadísticamente significativo." )
# Out:
# 11. Tabla ANOVA:
#                             df       sum_sq      mean_sq          F    PR(>F)
# promedio_examenes_cortos   1.0  1538.228959  1538.228959  38.492412  0.000032
# Residual                  13.0   519.504375    39.961875        NaN       NaN
#
# Interpretación de ANOVA:
#   El valor-p (PR(>F)) es extremadamente bajo (0.000032 < 0.05), por lo que
#   se rechaza H0. El modelo de regresión lineal es estadísticamente significativo.

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "salario" :[11, 10, 8, 5, 9, 7, 3, 11, 8, 7, 2, 9, 8, 3],
    "ausencias" :[18, 17, 29, 36, 11, 28, 35, 14, 20, 32, 39, 16, 31, 40]
})
df
# Out:
#     salario  ausencias
# 0        11         18
# 1        10         17
# 2         8         29
# 3         5         36
# 4         9         11
# 5         7         28
# 6         3         35
# 7        11         14
# 8         8         20
# 9         7         32
# 10        2         39
# 11        9         16
# 12        8         31
# 13        3         40

# %% [markdown]
# 1. **Establesca  una variable dependiente ($Y$) y una variable independiente ($X$).**
#
#  + $Y$: es el salario porque depende de las ausencias que tuvo.
#  + $X$: son las ausencias porque no depende de un factor.

# %%
# Y: salarios
# X: ausencias

X = df["ausencias"]
Y = df["salario"]

# %% [markdown]
# 2.**Realice un diagrama de dispersión para estos datos**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='orange',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'salario', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3.**¿Los datos soportan la suposición de linealidad?**
#
#    + si, porque existe una relacion en la forma de su estructura, ya que si tiene tendencia de linealidad.

# %% [markdown]
# 4.**Calcule el coeficiente de correlación e interprete el resultado.**

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación: -0.8801
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación es $r=-0.8801$, este valor indica que la correlcación es fuerte, dado que esta muy cerca de 1. Además, el que sea negativa, implica que aumentar las ausencias ($X$) disminuye el salario ($Y$)

# %% [markdown]
# 5. *Calcule el coeficiente de determinación e interprete el resultado

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo=sm.OLS(Y,x_constante).fit()
y_calculada =modelo.predict(x_constante)

# %%
#Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)
print(f"Coeficiente de determinación:{r2: 0.2%}")
# Out:
# Coeficiente de determinación: 77.46%

# %% [markdown]
# El coeficiente de determinación es $r^2=77.46$ esto quiere decir que la variabilidad en los salarios se debe alas ausencias que tuvo el trabajador, y el $22.54%$ que es el restante se debe a otros factores.

# %% [markdown]
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo=sm.OLS(Y,x_constante).fit()
y_calculada =modelo.predict(x_constante)

modelo.params
# Out:
# const        14.058843
# ausencias    -0.261814
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
#
# $$
# \hat{y}=14.058843-0.261814x
# $$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)


# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='orange',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Salarios', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )

# %% [markdown]
# La recta tiene la forma
# $$
# \hat{y}=by+b1X
# $$

# %%
# intervalo de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const      11.587445  16.530241
# ausencias  -0.350638  -0.172989

# %% [markdown]
# El verdadero $b_0$ está entre $11.587445$ y $16.530241$
# con una confianza del 95%. Esto indica que una persona sin ausencias ($X=0$) tiene una categoría de salario ($Y$) que está entre estos dos valores.
#
# El verdadero valor de $b_1$ está entre $-0.350638$ y $-0.172989$ con un 95% de confianza. Dado que dentre de este intervalo no esta el valor de cero, entonces  la relación es significativa. También indica que por cada falta se pierde entre 0.172989 y 0.350638 en la categoría de salario.

# %% [markdown]
# 8.**Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
residuales = modelo.resid

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)


# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='orange',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Ausencias', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Salario', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# Para los supuestos:
#
#  + Linealidad: Parece que sí, porque siguen una tendencia lineal negativa
#  + Normalidad: Si cumple con la normalidad, porque los puntos si se encuentran cerca de la linea y no existe una dispersión significativa.
#  + Homoscedasticidad: Si cumple con la homoscedasticidad ya que tiene una dispersión en toda la gráfica.
#  + Independencia: Si cumple, porque no tienen una relación entre estos estos.

# %% [markdown]
# 9.**Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro es el mas confiable
# n > 30, Histograma o Q-Q plot


#test de Shapiro-Wilk
1
#H0: Hay normalidad  0.0.4172971767713699
#H1: No hay normalidad


# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.4172971767713699

# %% [markdown]
# Dado que obtuvimos el $valor_p=0.41729$ es mayor que nuestro nivel de significancia $\alpha=0.05$ significa que no se rechaza la hipótesis nula $(H_0)$.

# %% [markdown]
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.8955

# %% [markdown]
# Nuestro resultado obtenido en $valor-p=0.8955$ es superiror a $\alpha=0.05$, no se se rechaza la hipótesis nula $(H_0)$.

# %% [markdown]
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.

# %%
import numpy as np

# mínimo ausencias: 11
#máximo ausencias: 40

# interpolar, valores de x entre 11 y 40

#interpolar 1
y_25 = modelo.predict([1, 25])
y_32 = modelo.predict([1, 32])

print(f"Para x = 25, y = {y_25[0]: 0.4f}")
print(f"Para x = 32, y = {y_32[0]: 0.4f}")
# Out:
# Para x = 25, y =  7.5135
# Para x = 32, y =  5.6808

# %% [markdown]
# La estimaciones son confiables ya que se logra apreciar que con mayor número de ausencias el nivel de salario disminuye.

# %%
df["salario_predicho"] = y_calculada.round()
df
# Out:
#     salario  ausencias  salario_predicho
# 0        11         18               9.0
# 1        10         17              10.0
# 2         8         29               6.0
# 3         5         36               5.0
# 4         9         11              11.0
# 5         7         28               7.0
# 6         3         35               5.0
# 7        11         14              10.0
# 8         8         20               9.0
# 9         7         32               6.0
# 10        2         39               4.0
# 11        9         16              10.0
# 12        8         31               6.0
# 13        3         40               4.0

# %%
# mínimo ausencias: 11
# máximo ausencias: 40

# Extrapolar, valores de x que no estén entre 11 y 40
y_10 = modelo.predict([[1, 10]])

print(f"Para x = 10, y = {y_10[0]: 0.4f}")
# Out:
# Para x = 10, y =  11.4407

# %% [markdown]
# 12.Realice una tabla ANOVA e interprete el resultado

# %%
df = pd.DataFrame({
    "salario" :[11, 10, 8, 5, 9, 7, 3, 11, 8, 7, 2, 9, 8, 3],
    "ausencias" :[18, 17, 29, 36, 11, 28, 35, 14, 20, 32, 39, 16, 31, 40]
})

# %%
import pandas as pd

df = pd.DataFrame({
    "salario" :[11, 10, 8, 5, 9, 7, 3, 11, 8, 7, 2, 9, 8, 3],
    "ausencias" :[18, 17, 29, 36, 11, 28, 35, 14, 20, 32, 39, 16, 31, 40]
})
df
# Out:
#     salario  ausencias
# 0        11         18
# 1        10         17
# 2         8         29
# 3         5         36
# 4         9         11
# 5         7         28
# 6         3         35
# 7        11         14
# 8         8         20
# 9         7         32
# 10        2         39
# 11        9         16
# 12        8         31
# 13        3         40

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols(
    '''salario ~ ausencias''',
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#              df     sum_sq    mean_sq          F    PR(>F)
# ausencias   1.0  87.034348  87.034348  41.243954  0.000033
# Residual   12.0  25.322795   2.110233        NaN       NaN

# %% [markdown]
# Teniendo los resultados de ANOVA obtuvimos el $valor-p(PR(>F))=0.000033$ comparandolo con nuestro nivel de significancia $\alpha=0.05$ podemos ver que es menor, por esto mismo se rechaza la hipótesis nula $(H_0)$

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "Gastos generales" :[191, 170, 272, 155, 280, 173, 234, 116, 153, 178],
    "Unidades" :[40, 42, 53, 35, 56, 39, 48, 30, 37, 40]
})
df
# Out:
#    Gastos generales  Unidades
# 0               191        40
# 1               170        42
# 2               272        53
# 3               155        35
# 4               280        56
# 5               173        39
# 6               234        48
# 7               116        30
# 8               153        37
# 9               178        40

# %% [markdown]
# 1. **Establesca una variable dependiente ($Y$) y una variable independiente ($X$).**
#
#    + $Y$ son los gastos generales porque dependen del nivel de producción.
#    + $X$ son las unidades porque no dependen de algo.

# %%
# Y: Gastos generales
# X: Unidades

X = df["Unidades"]
Y = df["Gastos generales"]

# %% [markdown]
# 2. **Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='green',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Gastos_generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3. **¿Los datos soportan la suposición de linealidad?**
#
#    + si, ya que los puntos se alinean visualmente y estos siguen una trayectoria recta.

# %% [markdown]
# 4. **Calcule el coeficiente de correlación e interprete el resultado**

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.9835
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación es $r=0.9835$, este valor nos indica que la correlación es fuerte ya que esta demaciado cerca de 1.

# %% [markdown]
# 5.**Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo=sm.OLS(Y,x_constante).fit()
y_calculada =modelo.predict(x_constante)

# %%
#Coeficiente de determinación
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)
print(f"Coeficiente de determinación:{r2: 0.2%}")
# Out:
# Coeficiente de determinación: 96.73%

# %% [markdown]
# Con el coeficiente de determinación $r^2=96.73$ nos dice que es muy cercano a un nivel alto de ser predicible, confirmando que las ausencias son un factor crítico.

# %% [markdown]
# 6.**Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo=sm.OLS(Y,x_constante).fit()
y_calculada =modelo.predict(x_constante)

modelo.params
# Out:
# const      -80.442857
# Unidades     6.491497
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
#
# $$
# \hat{y}=-80.442857+6.491497x
# $$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)


# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='green',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Gastos_generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 7.**Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )**

# %%
# intervalo de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const    -121.986373 -38.899341
# Unidades    5.518450   7.464543

# %% [markdown]
# El verdadero $b_0$ esta entre $-121.986373$ y $-38.899341$ con un 95% de confianza si la variable independiente fuera 0.
#
# El verdadero $b_1$ esta entre $5.5185$ y $7.464543$ con un nivel de confianza del 95%, esto significa que existe una relación lineal significativa entre las variables.

# %% [markdown]
# 8.**Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Recalculate residuals for the current model (Problem 3 data)
residuales = modelo.resid

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)


# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'Unidades', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'Gastos_generales', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# Para los supuestos:
# + Linealidad: Si cumple ya que la mayor parte de los puntos sigue una tendencia hacia el lado positivo.
# + Normalidad: Si cumple ya que todos los puntos se encuentran cerca de la linea.
# + Homoscedasticidad: Si cumple ya que los puntos se distribuyen de manera aleatoria
# + Independencia: Si se cumple por que las observaciones son individuales

# %% [markdown]
# 9.**Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro es el mas confiable
# n > 30, Histograma o Q-Q plot


#test de Shapiro-Wilk
1
#H0: Hay normalidad  0.0.4172971767713699
#H1: No hay normalidad


# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.22045077017698533

# %% [markdown]
# Dado que nuestro $valor-p=0.22045$ es mayor que nuestro nivel de significancia $\alpha=0.05$ nuestra hipotesis nula ($H_0$) no se rechaza.

# %% [markdown]
# 10.**Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.9858

# %% [markdown]
# Nuestro $valor-p=0.9858$ es mayor al nivel de significancia $\alpha=0.05$ quiere decir que no se rechaza la hipotesis nula ($H_0$)

# %% [markdown]
# 11.**Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %%
# mínimo ausencias: 30
#máximo ausencias: 56

# interpolar, valores de x entre 30 y 56

#interpolar 1
y_25 = modelo.predict([1, 25])
y_32 = modelo.predict([1, 32])

print(f"Para x = 25, y = {y_25[0]: 0.4f}")
print(f"Para x = 32, y = {y_32[0]: 0.4f}")
# Out:
# Para x = 25, y =  81.8446
# Para x = 32, y =  127.2850

# %% [markdown]
# tiene una prediccion alta de que sea confiable

# %%
df["Gastos generales_predicho"] = y_calculada.round(3)
df
# Out:
#    Gastos generales  Unidades  Gastos generales_predicho
# 0               191        40                    179.217
# 1               170        42                    192.200
# 2               272        53                    263.606
# 3               155        35                    146.760
# 4               280        56                    283.081
# 5               173        39                    172.726
# 6               234        48                    231.149
# 7               116        30                    114.302
# 8               153        37                    159.743
# 9               178        40                    179.217

# %%
# mínimo ausencias: 30
# máximo ausencias: 56

# Extrapolar, valores de x que no estén entre 30 y 56
y_10 = modelo.predict([[1, 10]])

print(f"Para x = 10, y = {y_10[0]: 0.4f}")
# Out:
# Para x = 10, y = -15.5279

# %% [markdown]
# 12.**Realice una tabla ANOVA e interprete el resultado.**

# %%
import pandas as pd

# Re-create the DataFrame for Problem 3 to ensure correct data is used
df = pd.DataFrame({
    "Gastos generales" :[191, 170, 272, 155, 280, 173, 234, 116, 153, 178],
    "Unidades" :[40, 42, 53, 35, 56, 39, 48, 30, 37, 40]
})

# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X (Y = Gastos generales, X = Unidades)
modelo_lineal = ols(
    '''Q('Gastos generales') ~ Q('Unidades')''',
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                 df        sum_sq       mean_sq           F        PR(>F)
# Q('Unidades')  1.0  24778.042517  24778.042517  236.669535  3.167080e-07
# Residual       8.0    837.557483    104.694685         NaN           NaN

# %% [markdown]
# Como resultado en el ANOVA en $PR(>F)=3.167080 o bien 0.0000003167$ esto es inferior a $\alpha=0.05$ con esto se rechaza la hipotesis nula y significa que nuestro modelo lineal si es confiable.

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "venta de línea blanca" :[5.0, 5.5, 6.0, 7.0, 7.2, 7.7, 8.4,9.0, 9.7, 10.0],
    "construcción de casas" :[2.0, 2.5, 3.2, 3.6, 3.7, 4.0, 4.2, 4.6, 4.8, 5.0]
})
df
# Out:
#    venta de línea blanca  construcción de casas
# 0                    5.0                    2.0
# 1                    5.5                    2.5
# 2                    6.0                    3.2
# 3                    7.0                    3.6
# 4                    7.2                    3.7
# 5                    7.7                    4.0
# 6                    8.4                    4.2
# 7                    9.0                    4.6
# 8                    9.7                    4.8
# 9                   10.0                    5.0

# %% [markdown]
# 1.**Establesca una variable dependiente ($Y$) y una variable independiente ($X$).**
#
# + $Y$: Venta de línea en blanca
# + $X$: Construcción de casas

# %%
# Y: Venta de línea blanca
# X: Construcción de casas

x = df["construcción de casas"]
y = df["venta de línea blanca"]

# %% [markdown]
# 2.**Realice un diagrama de dispersión para estos datos.**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'construcción de casas', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'venta de línea blanca', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3.**¿Los datos soportan la suposición de linealidad?**
# + Si soportan la linealidad ya que se sigue una relación en su forma de estructura y se dirigen los puntos hacia el lado poitivo

# %% [markdown]
# 4.**Calcule el coeficiente de correlación e interprete el resultado.**

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación:  0.9835
# valor_p:  0.0000

# %% [markdown]
# El coeficiente de correlación es de $r=0.9808$ al ser un valor cercano a 1, nos indica que existe una correlación lineal fuerte y positiva perfecta o casi perfecta. Quiere decir que segun aumenten la construcción de casas, las ventas en línea blanca aumentan constantemente.

# %% [markdown]
# 5.**Calcule el coeficiente de determinación e interprete el resultado.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo=sm.OLS(Y,x_constante).fit()
y_calculada =modelo.predict(x_constante)

# %%
# Coeficiente de determinacion
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)
print(f"Coeficiente de determinacion: {r2: 0.2%}")
# Out:
# Coeficiente de determinacion:  96.73%

# %% [markdown]
# El coeficiente de determinación es de $r^2=96.19%$. Quiere decir que el $96.19_%$ de la variabilidad en las ventas de línea se explica a través del número de casas.

# %% [markdown]
# 6.**Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo=sm.OLS(Y,x_constante).fit()
y_calculada =modelo.predict(x_constante)

modelo.params
# Out:
# const      -80.442857
# Unidades     6.491497
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
#
# $$
# \hat{y}=1.016760+1.737564
# $$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)


# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'construcción de casas', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'venta de línea blanca', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 7.**Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b1$)**

# %%
# intervalo de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                    0          1
# const    -121.986373 -38.899341
# Unidades    5.518450   7.464543

# %% [markdown]
# En $b_0$ tenemos que sus límites van de $-0.074848$ y $2.108368$ este intervalo si incluye a cero.
#
# En $b_1$ se encuentra entre $1.455693$ y $2.019435$ con un nivel de significancia del 95% esto quiere decir que existe una relación lineal significativa entre las variables.

# %% [markdown]
# 8.**Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Calcular los residuales
residuales = Y - y_calculada

# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50                  # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'construcción de casas', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'venta de línea blanca', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--', # Corrected: Removed the extra 'S'
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# Para los supuestos:
#
# + Linealidad: Si cumple ya que muestran una tendencia clara y positiva.
# + Normalidad: Si se cumple porque se distribuyen de forma normal.
# + Homoscedasticidad: Si cumple porque los puntos se mantienen dispersos a lo largo de la línea.
# + Independencia: Si se cumple ya que se encuentran dispersos los puntos.

# %% [markdown]
# 9.**Realice la prueba de Shapiro para los residuales y comente el resultado.**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro es el mas confiable
# n > 30, Histograma o Q-Q plot


#test de Shapiro-Wilk
1
#H0: Hay normalidad  0.0.4172971767713699
#H1: No hay normalidad


# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.22045077017698533

# %% [markdown]
# Dado que el $valor-p=0.846350$ es mayor que el nivel de $\alpha=0.05$ no se rechaza la hipotesis nula ($H_0$). Quiere decir que los residuos siguen una distribución normal de manera correcta.

# %% [markdown]
# 10.**Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.9858

# %% [markdown]
# Dado que obtuvimos el $valor-p=0.1581$ es mayor que el nivel de significancia $\alpha=0.05$ no se rechaza la hipótesis nula ($H_0$).

# %% [markdown]
# 11.**Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %%
# mínimo ausencias: 2
#máximo ausencias: 5

# interpolar, valores de x entre 2 y 5

#interpolar 1
y_2 = modelo.predict([1, 2])
y_4 = modelo.predict([1,4])

print(f"Para x = 3, y = {y_2[0]: 0.4f}")
print(f"Para x = 4, y = {y_4[0]: 0.4f}")
# Out:
# Para x = 3, y = -67.4599
# Para x = 4, y = -54.4769

# %% [markdown]
#  A medida que aumentan las ausencias ($x$), el valor de $y$ va aumentando

# %%
# mínimo ausencias: 2
# máximo ausencias: 4

# Extrapolar, valores de x que no estén entre 2 y 4
y_10 = modelo.predict([[1, 10]])

print(f"Para x = 10, y = {y_10[0]: 0.4f}")
# Out:
# Para x = 10, y = -15.5279

# %% [markdown]
# seguirá siendo perfectamente lineal a lo largo del tiempo

# %% [markdown]
# 12.**Realice una tabla ANOVA e interprete el resultado.**

# %%
# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

import statsmodels.api as sm
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols(
    '''Q("venta de línea blanca") ~ Q('construcción de casas')''',
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                              df     sum_sq    mean_sq           F  \
# Q('construcción de casas')  1.0  25.976581  25.976581  202.069951
# Residual                    8.0   1.028419   0.128552         NaN
#
#                                   PR(>F)
# Q('construcción de casas')  5.841003e-07
# Residual                             NaN

# %% [markdown]
# En nuestro ANOVA tenemos como resultado $PR(>F)= 5.84100$ inferior al nivel de significancia $\alpha=0.05$ con esto se rechaza la hipotesis nula con total confianza.

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd

df = pd.DataFrame({
    "número de interrupciones" : [ 5, 10, 10, 15, 15, 20, 20, 25],
    "calificación del trabajador" : [ 58, 41, 45, 27, 26, 12, 16, 3]

})
df
# Out:
#    número de interrupciones  calificación del trabajador
# 0                         5                           58
# 1                        10                           41
# 2                        10                           45
# 3                        15                           27
# 4                        15                           26
# 5                        20                           12
# 6                        20                           16
# 7                        25                            3

# %% [markdown]
# 1.**Establesca una variable dependiente ($Y$) y una variable independiente ($X$)**
#
# + $Y$ **calificación del trabajador en la prueba de hostilidad**
# + $X$ **número de interrupciones al trabajador**

# %%
# Y: calificación del trabajador
# X: número de interrupciones

X = df["número de interrupciones"]
Y = df["calificación del trabajador"]

# %% [markdown]
# 2.**Realice un diagrama de dispersión para estos datos**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='red',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'número de interrupciones', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'calificación del trabajador ', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 3.**¿Los datos soportan la suposición de linealidad?**
#
# + Si, soporta la linealidad ya que existe una relacion entre todos los puntos ya que siguen una tendencia en este caso se inclina hacia el lado negativo.

# %% [markdown]
# 4..**Calcule el coeficiente de correlación e interprete el resultado.**

# %%
# Importar la función pearsonr desde scipy.stats
from scipy.stats import pearsonr

# Test de Pearson
# H0: rho = 0     (No hay correlación)
# H1: rho ≠ 0     (Sí hay correlación)
# alpha = 0.05

r, valor_p = pearsonr(X, Y)

print(f"Coeficiente de correlación: {r: 0.4f}")
print(f'valor_p: {valor_p: 0.4f}')
# Out:
# Coeficiente de correlación: -0.9928
# valor_p:  0.0000

# %% [markdown]
# Tenemos como resultado un coeficiente de correlación $r=-0.9928$ quiere decir que existe una correlación negativa casi perfecta. Esto significa que por más interrupciones por parte del supervisor, menor es la calificación del trabajador.

# %% [markdown]
# 5.**Calcule el coeficiente de determinación e interprete el resultado**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo=sm.OLS(Y,x_constante).fit()
y_calculada =modelo.predict(x_constante)

# %%
# Coeficiente de determinacion
from sklearn.metrics import r2_score

r2 = r2_score(Y, y_calculada)
print(f"Coeficiente de determinacion: {r2: 0.2%}")
# Out:
# Coeficiente de determinacion:  98.58%

# %% [markdown]
# Tenemos como resultado en el coeficiente de determinación de $r^2=98.58%$ en la variabilidad de la calificación esto se explica de forma directa con el número de interrupciones, tiene una predicción muy cercana.

# %% [markdown]
# 6.**Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión**

# %%
import statsmodels.api as sm
x_constante = sm.add_constant(X)
modelo=sm.OLS(Y,x_constante).fit()
y_calculada =modelo.predict(x_constante)

modelo.params
# Out:
# const                       70.5
# número de interrupciones    -2.8
# dtype: float64

# %% [markdown]
# La ecuación de la recta es:
#
# $$
# \hat{y}=70.5-2.8x
# $$

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)


# Gráfico de dispersión
plt.scatter(
    X, Y,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='red',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'número de interrupciones', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'calificación del trabajador', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 7.**Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b1$)**

# %%
# intervalo de confianza
modelo.conf_int(alpha=0.05)
# Out:
#                                   0          1
# const                     65.051384  75.948616
# número de interrupciones  -3.136296  -2.463704

# %% [markdown]
# 8.**Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?**

# %%
# Importamos la librería matplotlib.pyplot y le damos el pseudónimo plt
import matplotlib.pyplot as plt

# Recalculate residuals for the current model (Problem 3 data)
residuales = modelo.resid

# Configuración general del gráfico
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)


# Gráfico de dispersión
plt.scatter(
    X, residuales,
    marker="o",       # forma: googlear "matplotlib.markers"
    color='red',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.8,            # transparencia: 0 es invisible y 1 es color sólido
    s=50,                 # tamaño de los puntos
)

 #Gráfico de línea
plt.plot(
    X,y_calculada * 0,
    color='black',   # color de la línea
    linewidth=1.0,        # grosor de la línea
    linestyle='--',        # estilo de línea
    label='Recta de regresión'
)

# Etiquetas de los ejes
# eje x
plt.xlabel(
    'número de interrupciones', # etiqueta del eje x
    fontsize=12  # tamaño de fuente
)

plt.ylabel(
    'calificación del trabajador', # etiqueta del eje y
    fontsize=12 # tamaño de fuente
)

# Fuente de los ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Márgenes
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Cuadrícula (opcional, pero didáctica)
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.5,
    color="gray"
)

# %% [markdown]
# 9.**Realice la prueba de Shapiro para los residuales y comente el resultado**

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

# n < 30, Shapiro es el mas confiable
# n > 30, Histograma o Q-Q plot


#test de Shapiro-Wilk
1
#H0: Hay normalidad  0.0.4172971767713699
#H1: No hay normalidad


# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 0.054816491127669634

# %% [markdown]
# 10.**Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.**

# %%
# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
import statsmodels.api as sm
x_constante = sm.add_constant(X)
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor-p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor-p de Breusch-Pagan:  0.2482

# %% [markdown]
# 11.**Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.**

# %%
# mínimo ausencias: 5
#máximo ausencias: 25

# interpolar, valores de x entre 5 y 25

#interpolar 1
y_12 = modelo.predict([1, 12])
y_20 = modelo.predict([1, 20])

print(f"Para x = 12, y = {y_12[0]: 0.4f}")
print(f"Para x = 20, y = {y_20[0]: 0.4f}")
# Out:
# Para x = 12, y =  36.9000
# Para x = 20, y =  14.5000

# %% [markdown]
# Teniendo estos resultados muestran un sentido de logica

# %%
# mínimo ausencias: 5
# máximo ausencias: 25

# Extrapolar, valores de x que no estén entre 5 y 25
y_30 = modelo.predict([[1, 30]])

print(f"Para x = 30, y = {y_30[0]: 0.4f}")
# Out:
# Para x = 30, y = -13.5000

# %% [markdown]
# 12.**Realice una tabla ANOVA e interprete el resultado.**

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Re-create the DataFrame for Problem 5
df = pd.DataFrame({
    "número de interrupciones al trabajador" : [ 5, 10, 10, 15, 15, 20, 20, 25],
    "calificación del trabajador en la prueba de hostilidad" : [ 58, 41, 45, 27, 26, 12, 16, 3]
})

# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

# Y ~ X
modelo_lineal = ols(
    "Q('calificación del trabajador en la prueba de hostilidad') ~ Q('número de interrupciones al trabajador')",
    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                               df  sum_sq      mean_sq  \
# Q('número de interrupciones al trabajador')  1.0  2352.0  2352.000000
# Residual                                     6.0    34.0     5.666667
#
#                                                       F        PR(>F)
# Q('número de interrupciones al trabajador')  415.058824  9.090964e-07
# Residual                                            NaN           NaN

# %% [markdown]
# Tenemos como resultado en nuestra $PR(>F)=9.09090_o_bien 0.000000909$ esto es inferior a $\alpha=0.05$ donde podemos ver que se rechaza la hipotesis nula, esto concluye que el número de interrupciones si tiene un impacto al trabajador.
